# %% [markdown]
# #  Problem:
#
# ## Analyze the “auto mpg data” and draw a pair plot using seaborn library for mpg, weight, and origin.

# %%
# importing libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

import seaborn as sns

# %%
# importing dataset
dataset = pd.read_csv('auto_data.csv')

# viewing the dataset
dataset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
datset['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
# lets consider origin as -->> 1->USA, 2->Russia, 3-Asia

def region_of_origin(num):
    if num == 1:
        return 'USA'
    if num == 2:
        return 'Russia'
    if num == 3:
        return 'Asia'

dataset['origin'] = dataset['origin'].apply(region_of_origin)

# %%
# viewing the dataset
dataset
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70     USA  chevrolet chevelle malibu
# ...

# %%
# draw the pair plot using sns for mpg, weight, origin and with hue origin, set the size to 4
# note: hue is variable in dataset to map plot aspects to different colors

columns_ = ['mpg', 'weight', 'origin']
sns.pairplot(dataset[columns_], hue = 'origin', height = 4)

# %% [markdown]
# # End
